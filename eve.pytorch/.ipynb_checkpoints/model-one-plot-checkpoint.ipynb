# %%
import pickle


# with open ("eve-loss-0.71-model-vgg16-0.001-0.0001.txt", 'rb') as fp:
#     eve_loss = pickle.load(fp)
# with open ("eve-test-loss-model-vgg16-0.001-0.0001.txt", 'rb') as fp:
#     eve_test_loss = pickle.load(fp)
# with open ("eve-loss-model-vgg16-0.001-0.0001-4-16.txt", 'rb') as fp:
#     eve_loss = pickle.load(fp)
# with open ("eve-dt-model-vgg16-0.001-0.0001.txt", 'rb') as fp:
#     eve_dt= pickle.load(fp)
# with open ("eve-loss-list-model-vgg16-0.001.txt", 'rb') as fp:
#     eve_loss_list33 = pickle.load(fp)
with open ("eve-loss-0.14new-model-one-lr-0.001-0.0001.txt", 'rb') as fp:
    eve_loss = pickle.load(fp)
with open ("adam-loss-model-32-64-512-10-lr-0.001.txt", 'rb') as fp:
    adam_loss = pickle.load(fp)
with open ("rms-loss-model-32-64-512-10-lr-0.001.txt", 'rb') as fp:
    rms_loss = pickle.load(fp)

with open ("ada-loss-model-one-lr-0.01.txt", 'rb') as fp:
    ada_loss = pickle.load(fp)

# %%
import pickle


with open ("eve-test-acc-0.14-model-one-lr-0.001-0.0001.txt", 'rb') as fp:
    eve_test_acc = pickle.load(fp)
with open ("adam-test-acc-model-32-64-512-10-lr-0.001.txt", 'rb') as fp:
    adam_test_acc = pickle.load(fp)
with open ("rms-test-acc-model-32-64-512-10-lr-0.001.txt", 'rb') as fp:
    rms_test_acc = pickle.load(fp)
with open ("ada-test-acc-model-one-lr-0.01.txt", 'rb') as fp:
    ada_test_acc = pickle.load(fp)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np


# plt.rcParams['figure.figsize'] = (20.0, 16.0) # set default size of plots
# plt.rcParams['image.interpolation'] = 'nearest'
# plt.rcParams['image.cmap'] = 'gray'


plt.plot(np.arange(5, 20, 1), eve_loss[5:20])

plt.plot(np.arange(5, 20, 1), adam_loss[5:20])


plt.plot(np.arange(5, 20, 1), rms_loss[5:20])


plt.plot(np.arange(5, 20, 1), ada_loss[5:20])

plt.grid(ls=":")
plt.xlabel("Epochs")
plt.ylabel("Training cross-entropy loss")
plt.legend(["Lilin", "Adam", "RMSprop", "Adagrad"])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt


plt.plot(eve_loss)

plt.plot(adam_loss)


plt.plot(rms_loss)




plt.plot(ada_loss)

plt.grid(ls=":")
plt.xlabel("Epochs")
plt.ylabel("Training cross-entropy loss")
plt.legend(["Lilin", "Adam", "RMSprop", "Adagrad"])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
# plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
# plt.rcParams['image.interpolation'] = 'nearest'
# plt.rcParams['image.cmap'] = 'gray'

plt.plot(eve_test_acc)
plt.plot(adam_test_acc)

plt.plot(rms_test_acc)


plt.plot(ada_test_acc)

# plt.grid(True)
plt.xlabel("Epochs")
plt.ylabel("Test accuracy")
plt.grid(ls=":")

plt.legend(["Lilin", "Adam", "RMSprop","Adagrad"])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(np.arange(40, 50, 1), eve_test_acc[40:51])
plt.plot(np.arange(40, 50, 1), adam_test_acc[40:51])

plt.plot(np.arange(40, 50, 1), rms_test_acc[40:51])


plt.plot(np.arange(40, 50, 1), ada_test_acc[40:51])

plt.xlabel("Epochs")
plt.ylabel("Test accuracy")
plt.grid(ls=":")

plt.legend(["Lilin", "Adam", "RMSprop","Adagrad"])

# %%
import pickle
with open ("range-test-val-acc-list-model-one-iters1477-0.05-8epochs.txt", 'rb') as fp:
    d22 = pickle.load(fp)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np
x = np.arange(0, 1477*0.05/(8*391), 0.05/(8*391))
plt.plot(x, d22)


plt.xlabel("Iterations")
plt.ylabel("Test accuracy")
plt.grid(ls=":")

# %%
x = np.arange(0, 1477*0.05/(8*391), 0.05/(8*391))[350:600]
plt.plot(x, d22[350:600])


plt.xlabel("Iterations")
plt.ylabel("Test accuracy")
plt.grid(ls=":")
