# %%
from eve import Eve

import torch
import torch.nn as nn
from torch.autograd import Variable

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
import utils
from utils import *

# %%
# variables
batch_size = 128
cuda = torch.cuda.is_available()

# load data
transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                                ])
train_loader = torch.utils.data.DataLoader(
    datasets.CIFAR10('data/cifar10', train=True, download=True,
                     transform=transform),
    batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(
    datasets.CIFAR10('data/cifar10', train=False, transform=transform),
    batch_size=batch_size, shuffle=True)
# Out:
# Files already downloaded and verified

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, 3, stride=1)
        self.conv2 = nn.Conv2d(32, 32, kernel_size=3)

        self.conv3 = nn.Conv2d(32, 64, kernel_size=3)
        self.conv4 = nn.Conv2d(64, 64, kernel_size=3)
        self.dense1 = nn.Linear(in_features=64 * 25, out_features=512)
        self.dense1_bn = nn.BatchNorm1d(512)
        self.dense2 = nn.Linear(512, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(F.dropout(F.max_pool2d(self.conv2(x), 2), 0.25))
        x = F.relu(self.conv3(x))
        x = F.relu(F.dropout(F.max_pool2d(self.conv4(x), 2), 0.25))
        x = x.view(-1, 64 * 25)  # reshape
        x = F.relu(self.dense1_bn(self.dense1(x)))
        return F.log_softmax(self.dense2(x))

# %%
def train(epoch_index, model, optimizer):
    model.train()
    for batch_index, (data, target) in enumerate(train_loader):
        if cuda:
            data, target = data.cuda(), target.cuda()
        data, target = Variable(data), Variable(target)
        
        def closure():
            optimizer.zero_grad()  # reset optimizer
            output = model(data)
            loss = F.nll_loss(output, target)  # negative log likelihood loss
            loss.backward()  # backprop
            return loss
        
        lr = lr_increased_linearly(epoch_index=epoch_index, batch_index=batch_index+1)
        optimizer = optim.SGD(model.parameters(), lr=lr)
        loss = optimizer.step(closure)
        val_accuracy = test(batch_index, model)
        val_accuracy_list.append(val_accuracy)
        if batch_index % 390 == 0:
            print('\rOne epoch train end: {} Loss: {}'.format(epoch_index, loss))
        # eval model
         
    return 'success'

# %%
def test(batch_index, model):
    model.eval()
    test_loss = 0
    correct = 0
    for data, target in test_loader:
        if cuda:
            data, target = data.cuda(), target.cuda()
        data, target = Variable(data), Variable(target)
        output = model(data)
        pred = output.data.max(1)[1]  # get the index of the max log-probability
        correct += pred.eq(target.data).cpu().sum()
        val_accuracy = correct / len(test_loader.dataset)

    print('\nTest set: batch_index {} Accuracy: {}/{} ({:.2%})'.format(
        batch_index, correct, len(test_loader.dataset), val_accuracy
        ))
    return val_accuracy


def plot(accuracy_list, filename):
    import matplotlib
    import numpy as np
    matplotlib.use("AGG")
    import matplotlib.pyplot as plt
    plt.plot(accuracy_list)
    plt.xlabel("Learning rate")
    plt.ylabel("Accuracy")
    plt.xticks(np.arange(0, 0.05, 0.005))
    plt.savefig(filename)
    plt.clf()
    
# linearly increase learning rate for purpose of determine the converged learning rate.
def lr_increased_linearly(epoch_index, batch_index):
    lr_max = 0.05
    batch_num = 391
    epoch_num = 8
    lr = 0.05 * (epoch_index / epoch_num) * (batch_index+1) / (batch_num)
    return lr

# %%
epoch_num = 8
print("sgd")
val_accuracy_list= []
model = Net()
if cuda:
    model.cuda()
optimizer = optim.SGD(model.parameters(), lr=0.01)
for epoch_index in range(1, epoch_num + 1):
    lr = lr_increased_linearly(epoch_index, batch_index=1)
    optimizer = optim.SGD(model.parameters(), lr=lr)
    result = train(epoch_index, model, optimizer)
    print (result)

plot(val_accuracy_list, "accuracy.png")
# Out:
# sgd
#
# Test set: batch_index 0 Accuracy: 960/10000 (9.60%)
# One epoch train end: 1 Loss: Variable containing:
#  2.3066
# [torch.cuda.FloatTensor of size 1 (GPU 0)]
#
#
# Test set: batch_index 1 Accuracy: 960/10000 (9.60%)
#
# Test set: batch_index 2 Accuracy: 959/10000 (9.59%)
#
# Test set: batch_index 3 Accuracy: 957/10000 (9.57%)
#
# Test set: batch_index 4 Accuracy: 960/10000 (9.60%)
#
# Test set: batch_index 5 Accuracy: 960/10000 (9.60%)
#
# Test set: batch_index 6 Accuracy: 958/10000 (9.58%)
#
# Test set: batch_index 7 Accuracy: 957/10000 (9.57%)
#
# Test set: batch_index 8 Accuracy: 957/10000 (9.57%)
#
# Test set: batch_index 9 Accuracy: 957/10000 (9.57%)
#
# Test set: batch_index 10 Accuracy: 957/10000 (9.57%)
#
# Test set: batch_index 11 Accuracy: 958/10000 (9.58%)
#
# Test set: batch_index 12 Accuracy: 959/10000 (9.59%)
# ---------------------------------------
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-8-16e973497ec9> in <module>()
# ...

# %%
len(val_accuracy_list)

# %%
val_accuracy_list_initialized = [0] * 157

# %%
def average_by_twenty(val_accuracy_list_initialized, val_accuracy_list):
    target_len = len(val_accuracy_list_initialized)
    for i in range(target_len):
        counter = 0
        if i != target_len - 1:
            while counter < 20:
                val_accuracy_list_initialized[i] += val_accuracy_list[i*20 + counter]
                counter += 1
            val_accuracy_list_initialized[i] /= 20  
        else:
            while counter < 8:
                val_accuracy_list_initialized[i] += val_accuracy_list[i*20 + counter]
                counter += 1
            val_accuracy_list_initialized[i] /= 8
    return val_accuracy_list_initialized

# %%
val_accuracy_list_average = average_by_ten(val_accuracy_list_initialized, val_accuracy_list)

# %%
val_accuracy_list_average_twenty = average_by_twenty(val_accuracy_list_initialized, val_accuracy_list)

# %%
val_accuracy_list_average
# Out:
# [0.09519999999999999,
#  0.09517,
#  0.09523000000000001,
#  0.09505999999999999,
#  0.09506,
#  0.09488999999999999,
#  0.09492,
#  0.09455000000000001,
#  0.0939,
#  0.09337999999999999,
#  0.09303999999999998,
#  0.09391000000000001,
#  0.09468000000000001,
#  0.09473000000000001,
#  0.09506999999999999,
#  0.09510999999999999,
#  0.09536,
#  0.09622,
#  0.09560000000000002,
#  0.09418,
#  0.09480999999999999,
#  0.09471,
#  0.09446,
#  0.09344,
#  0.09396999999999998,
#  0.09647000000000001,
#  0.09525,
#  0.09430999999999999,
#  0.09473000000000001,
#  0.09481999999999999,
#  0.09601000000000001,
#  0.09597999999999998,
#  0.09440000000000001,
#  0.09379,
#  0.0939,
#  0.09546999999999999,
#  0.09739,
#  0.09883,
#  0.09929000000000002,
#  0.09942000000000002,
#  0.09940000000000002,
#  0.09948000000000003,
#  0.09951000000000002,
#  0.09952000000000003,
#  0.09952000000000003,
#  0.09944000000000001,
#  0.09932999999999999,
#  0.09888999999999999,
#  0.09888999999999999,
# ...

# %%
x = 0
for i in range(10):
    x += val_accuracy_list[i]

# %%
x
# Out:
# 0.952

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (20.0, 16.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
import numpy as np
plt.plot(np.arange(0, 0.05, 20 * 0.05/(8*391)), val_accuracy_list_average_twenty)
plt.xlabel("Learning rate")
plt.ylabel("Accuracy")
plt.savefig("accuracy_average_twenty_large.png")

# %%
import pickle
with open ("eve-loss-model-32-64-512-10-lr-0.001-0.0001.txt", 'rb') as fp:
    eve_loss = pickle.load(fp)
# with open ("ada-loss-model-32-64-512-10-lr-0.001.txt", 'rb') as fp:
#     ada_loss001 = pickle.load(fp)
# with open ("ada-loss-model-32-64-512-10-lr-0.1.txt", 'rb') as fp:
#     ada_loss1 = pickle.load(fp)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
# plt.plot(eve_test_accuracy)

# plt.plot(eve_test_accuracy_6)

# plt.plot(adam_test_accuracy)
# plt.plot(eve_test_accuracy6)

# plt.plot(eve_test_accuracy)
# plt.plot(eve_test_loss)

# plt.plot(eve_test_loss6)
plt.plot(eve_loss[40:49])

# plt.plot(ada_loss001)

# plt.plot(ada_loss1)





# plt.plot(adam_test_accuracy)
# plt.plot(adam_loss_0)


plt.legend(["0.01", "0.001", "0.1",])


# plt.plot(eve_dt6[25000:30000])
