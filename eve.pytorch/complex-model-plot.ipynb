# %%
import numpy as np
import pickle

# %%
lr_linear = [0]*391*50
for i in range(391*50):
    lr_linear[i] = 0.001  * (1 - (i+1)/(391*50))
    
lr_sqrt = [0]*391*50
for i in range(391*50):
    lr_sqrt[i] = 0.001  * np.sqrt(1 - (i+1)/(391*50))
    
lr_square = [0]*391*50
for i in range(391*50):
    lr_square[i] = 0.001  * np.square(1 - (i+1)/(391*50))
    
lr_fix = [0.001]*15*391 + [0.0001]*15*391 + [0.00001]*20*391

# %%
with open ("cycle-loss-model-vgg16-0.005-4-52.txt", 'rb') as fp:
    cycle_loss005a4 = pickle.load(fp)
with open ("cycle-loss-model-vgg16-0.01-4-52.txt", 'rb') as fp:
    cycle_loss01a4 = pickle.load(fp)
with open ("cycle-loss-model-vgg16-0-0.01-4-52-with-dt.txt", 'rb') as fp:
    cycle_loss01e4 = pickle.load(fp)


with open ("cycle-test-loss-model-vgg16-0.005-4-52.txt", 'rb') as fp:
    cycle_test_loss005a4 = pickle.load(fp)
with open ("cycle-test-loss-model-vgg16-0.01-4-52.txt", 'rb') as fp:
    cycle_test_loss01a4 = pickle.load(fp)
with open ("cycle-test-loss-model-vgg16-0-0.01-4-52-with-dt.txt", 'rb') as fp:
    cycle_test_loss01e4 = pickle.load(fp)

    
with open ("cycle-test-acc-model-vgg16-0.005-4-52.txt", 'rb') as fp:
    cycle_test_acc005a4 = pickle.load(fp)
with open ("cycle-test-acc-vgg16-0.0007-0-0.01-4-52.txt", 'rb') as fp:
    cycle_test_acc01a4 = pickle.load(fp)
with open ("cycle-test-acc-vgg16-0.0007-0-0.01-4-52-with-dt.txt", 'rb') as fp:
    cycle_test_acc01e4 = pickle.load(fp)

# %%
with open ("eve-loss-model-vgg16-0.001-0.0001-v3.txt", 'rb') as fp:
    eve_loss = pickle.load(fp)
with open ("adam-loss-model-vgg16-0.001-0.0001-v3.txt", 'rb') as fp:
    adam_loss = pickle.load(fp)
with open ("rms-loss-model-vgg16-0.001-0.0001-v3.txt", 'rb') as fp:
    rms_loss = pickle.load(fp)
with open ("ada-loss-model-vgg16-0.001.txt", 'rb') as fp:
    ada_loss = pickle.load(fp)
    
with open ("eve-test-loss-model-vgg16-0.001-0.0001-v3.txt", 'rb') as fp:
    eve_test_loss = pickle.load(fp)
with open ("adam-test-loss-model-vgg16-0.001-0.0001-v3.txt", 'rb') as fp:
    adam_test_loss = pickle.load(fp)
with open ("rms-test-loss-model-vgg16-0.001-0.0001-v3.txt", 'rb') as fp:
    rms_test_loss = pickle.load(fp)
with open ("ada-test-loss-model-vgg16-0.001.txt", 'rb') as fp:
    ada_test_loss = pickle.load(fp)
    

# with open ("eve-dt-model-vgg16-0.001-0.0001.txt", 'rb') as fp:
#     eve_dt= pickle.load(fp)
# with open ("eve-loss-list-model-vgg16-0.001.txt", 'rb') as fp:
#     eve_loss_list33 = pickle.load(fp)

# %%
## my zoo

# %%
with open ("eve-loss-model-vgg16-0.001-0.0001-v3-0.1-4-28-dt.txt", 'rb') as fp:
    eve_loss01e4 = pickle.load(fp)
with open ("eve-loss-model-vgg16-0.001-0.0001-v3-0.01-8-24-dt.txt", 'rb') as fp:
    eve_loss01e8 = pickle.load(fp)
with open ("eve-loss-model-vgg16-0.001-0.0001-v3-0.005-4-28-dt.txt", 'rb') as fp:
    eve_loss005e4 = pickle.load(fp)
with open ("eve-loss-model-vgg16-0.001-0.0001-v3-0.005-8-24-dt.txt", 'rb') as fp:
    eve_loss005e8 = pickle.load(fp)

with open ("eve-test-loss-model-vgg16-0.001-0.0001-v3-0.1-4-28-dt.txt", 'rb') as fp:
    eve_test_loss01e4 = pickle.load(fp)
with open ("eve-test-loss-model-vgg16-0.001-0.0001-v3-0.01-8-24-dt.txt", 'rb') as fp:
    eve_test_loss01e8 = pickle.load(fp)
with open ("eve-test-loss-model-vgg16-0.001-0.0001-v3-0.005-4-28-dt.txt", 'rb') as fp:
    eve_test_loss005e4 = pickle.load(fp)
with open ("eve-test-loss-model-vgg16-0.001-0.0001-v3-0.005-8-24-dt.txt", 'rb') as fp:
    eve_test_loss005e8 = pickle.load(fp)
    
with open ("eve-test-acc-model-vgg16-0.001-0.0001-v3-0.1-4-28-dt.txt", 'rb') as fp:
    eve_test_acc01e4 = pickle.load(fp)
with open ("eve-test-acc-model-vgg16-0.001-0.0001-v3-0.01-8-24-dt.txt", 'rb') as fp:
    eve_test_acc01e8 = pickle.load(fp)
with open ("eve-test-acc-model-vgg16-0.001-0.0001-v3-0.005-4-28-dt.txt", 'rb') as fp:
    eve_test_acc005e4 = pickle.load(fp)
with open ("eve-test-acc-model-vgg16-0.001-0.0001-v3-0.005-8-24-dt.txt", 'rb') as fp:
    eve_test_acc005e8 = pickle.load(fp)

# %%
# decay zoo

# %%
with open("eve-loss-model-vgg16-0.001-square-decay.txt", 'rb') as fp:
    eve_losssquare= pickle.load(fp)
# with open("eve-loss-list-model-vgg16-0.001-square-decay.txt", 'rb') as fp:
#     eve_loss_listsquare = pickle.load(fp)
with open("eve-test-loss-model-vgg16-0.001-square-decay.txt", 'rb') as fp:
    eve_test_losssquare = pickle.load(fp)
with open("eve-test-acc-model-vgg16-0.001-square-decay.txt", 'rb') as fp:
    eve_test_accsquare = pickle.load(fp)
# with open("eve-trn-acc-model-vgg16-0.001-square-decay.txt", 'rb') as fp:
#     eve_trn_accsquare = pickle.load(fp)
# with open("eve-dt-model-vgg16-0.001-square-decay.txt", 'rb') as fp:
#     eve_dtsquare = pickle.load(fp)

# %%
with open("eve-loss-model-vgg16-0.001-sqrt-decay.txt", 'rb') as fp:
    eve_losssqrt= pickle.load(fp)
with open("eve-test-loss-model-vgg16-0.001-sqrt-decay.txt", 'rb') as fp:
    eve_test_losssqrt = pickle.load(fp)
with open("eve-test-acc-model-vgg16-0.001-sqrt-decay.txt", 'rb') as fp:
    eve_test_accsqrt = pickle.load(fp)

# %%
with open("eve-loss-model-vgg16-0.001-v2.txt", 'rb') as fp:
    eve_losslinear= pickle.load(fp)
with open("eve-test-loss-model-vgg16-0.001-v2.txt", 'rb') as fp:
    eve_test_losslinear = pickle.load(fp)
with open("eve-test-acc-model-vgg16-0.001-v2.txt", 'rb') as fp:
    eve_test_acclinear = pickle.load(fp)

# %%
with open("eve-loss-model-vgg16-0.001-fixed-step.txt", 'rb') as fp:
    eve_lossfix= pickle.load(fp)
with open("eve-test-loss-model-vgg16-0.001-fixed-step.txt", 'rb') as fp:
    eve_test_lossfix = pickle.load(fp)
with open("eve-test-acc-model-vgg16-0.001-fixed-step.txt", 'rb') as fp:
    eve_test_accfix = pickle.load(fp)

# %%
with open("eve-loss-model-vgg16-0.001-early-stop.txt", 'rb') as fp:
    eve_lossearly= pickle.load(fp)
with open("eve-test-loss-model-vgg16-0.001-early-stop.txt", 'rb') as fp:
    eve_test_lossearly = pickle.load(fp)
with open("eve-test-acc-model-vgg16-0.001-early-stop.txt", 'rb') as fp:
    eve_test_accearly = pickle.load(fp)

# %%
with open("eve-loss-model-vgg16-0.001-0.0001-v3.txt", 'rb') as fp:
    eve_lossexp= pickle.load(fp)
with open("eve-test-loss-model-vgg16-0.001-0.0001-v3.txt", 'rb') as fp:
    eve_test_lossexp = pickle.load(fp)
with open("eve-test-acc-model-vgg16-0.001-0.0001-v3.txt", 'rb') as fp:
    eve_test_accexp = pickle.load(fp)

# %%
with open("eve-lr-lst-model-vgg16-0.001-0.001-v3.txt", 'rb') as fp:
    lr_exp = pickle.load(fp)

# %%
with open ("eve-test-acc-model-vgg16-0.001-0.0001-v3.txt", 'rb') as fp:
    accv3= pickle.load(fp)

# %%
with open ("eve-loss-model-vgg16-0.001-0.0001-4-28-0-0.01-with-dt.txt", 'rb') as fp:
    loss01 = pickle.load(fp)
# with open ("adam-test-loss-model-vgg16-0.001-0.0001.txt", 'rb') as fp:
#     adam_test_loss = pickle.load(fp)
# with open ("rms-test-loss-model-vgg16-0.001-0.0001.txt", 'rb') as fp:
#     rms_test_loss = pickle.load(fp)
# with open ("ada-test-loss-model-vgg16-0.01.txt", 'rb') as fp:
#     ada_test_loss = pickle.load(fp)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
# plt.rcParams['figure.figsize'] = (20.0, 16.0) # set default size of plots
# plt.rcParams['image.interpolation'] = 'nearest'
# plt.rcParams['image.cmap'] = 'gray'

# %%
len(ada_loss[0][1])
# Out:
# 391

# %%
_ada_loss = [0]*50
for i in range(50):
    _ada_loss[i] = ada_loss[i][0]

# %%
# %matplotlib inline


import matplotlib.pyplot as plt

plt.plot(eve_loss01e4)

plt.plot(eve_lossexp)

plt.plot(eve_losslinear)

plt.plot(eve_losssqrt)

plt.plot(eve_losssquare)

plt.plot(eve_lossfix)

plt.plot(eve_lossearly)


# plt.plot(eve_loss)

# plt.plot(adam_loss)


# plt.plot(rms_loss)

# plt.plot(ada_loss)



# plt.plot(eve_loss01e8)
# plt.plot(eve_loss005e4)
# plt.plot(eve_loss005e8)

# plt.plot(cycle_loss005a4)
# plt.plot(cycle_loss01a4)
# plt.plot(cycle_loss01e4)
    
plt.grid(ls=":")
plt.xlabel("Epochs")
plt.ylabel("Training cross-entropy loss")
# plt.legend(["Lilin", "Adam", "RMSprop", "Adagrad"])
# plt.legend(["learning rate 0.01 4epochs", "learning rate 0.01 8epochs", "learning rate 0.005 4epochs", "learning rate 0.005 8epochs"])
# plt.legend(["005a4", "01a4", "01e4"])
plt.legend(["cyclic decay", "1/t decay", "linear decay", "square root decay", "square decay","fixed step decay", "fixed step decay manually"])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# plt.plot(np.arange(5, 20, 1), eve_loss[5:20])

# plt.plot(np.arange(5, 20, 1), adam_loss[5:20])


# plt.plot(np.arange(5, 20, 1), rms_loss[5:20])


# plt.plot(np.arange(5, 20, 1), ada_loss[5:20])
# plt.plot(np.arange(40, 54, 1), eve_loss01e4[40:])
# plt.plot(np.arange(40, 50, 1), eve_loss01e8[40:])
# plt.plot(np.arange(40, 54, 1), eve_loss005e4[40:])
# plt.plot(np.arange(40, 50, 1), eve_loss005e8[40:])
plt.plot(eve_loss01e4)

plt.plot(eve_lossexp)

plt.plot(eve_losslinear)

plt.plot(eve_losssqrt)

plt.plot(eve_losssquare)

plt.plot(eve_lossfix)

plt.plot(eve_lossearly)
plt.legend(["cyclic decay", "1/t decay", "linear decay", "square root decay", "square decay","fixed step decay", "fixed step decay manually"])


plt.grid(ls=":")
plt.xlabel("Epochs")
plt.ylabel("Training cross-entropy loss")
# plt.legend(["Lilin", "Adam", "RMSprop", "Adagrad"])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
# plt.rcParams['figure.figsize'] = (20.0, 16.0) # set default size of plots
# plt.rcParams['image.interpolation'] = 'nearest'
# plt.rcParams['image.cmap'] = 'gray'


# plt.plot(eve_test_acc)
# plt.plot(adam_test_acc)
# plt.plot(rms_test_acc)
# plt.plot(ada_test_acc)
plt.plot(eve_test_acc01e4[:50])
plt.plot(eve_test_accexp)

plt.plot(eve_test_acclinear)

plt.plot(eve_test_accsqrt)

plt.plot(eve_test_accsquare)

plt.plot(eve_test_accfix)

plt.plot(eve_test_accearly)
# plt.plot(eve_test_acc01e8)
# plt.plot(eve_test_acc005e4)
# plt.plot(eve_test_acc005e8)

# plt.plot(cycle_test_acc005a4)
# plt.plot(cycle_test_acc01a4)
# plt.plot(cycle_test_acc01e4)

plt.xlabel("Epochs")
plt.ylabel("Test Accuracy")
plt.grid(ls=":")
# plt.legend(["Lilin", "Adam", "RMSprop","Adagrad"])
# plt.legend(["learning rate 0.01 4epochs", "learning rate 0.01 8epochs", "learning rate 0.005 4epochs", "learning rate 0.005 8epochs"])
# plt.legend(["Lilin with cyclic decay", "cyclic decay over Lilin"])


plt.legend(["cyclic decay", "1/t decay", "linear decay", "square root decay", "square decay","step decay", "step decay heuristically"])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
xx = [41, 45, 49]
yy = [eve_test_acc01e4[41], eve_test_acc01e4[45], eve_test_acc01e4[49]]
plt.scatter(xx,yy,s=20, c='r')

x =np.arange(40, 50, 1)


# plt.plot(x, eve_test_acc[40:50])
# plt.plot(x, adam_test_acc[40:50])
# plt.plot(x, rms_test_acc[40:50])
# plt.plot(x, ada_test_acc[40:50])
# plt.plot(x, eve_test_accexp[40:50])

plt.plot(x, eve_test_acc01e4[40:50])
plt.plot(x, eve_test_accexp[40:50])

plt.plot(x, eve_test_acclinear[40:50])

plt.plot(x, eve_test_accsqrt[40:50])

plt.plot(x, eve_test_accsquare[40:50])

plt.plot(x, eve_test_accfix[40:50])

plt.plot(x, eve_test_accearly[40:50])

# plt.plot(np.arange(40, 50, 1), eve_test_acc01e8[40:])
# plt.plot(np.arange(40, 54, 1), eve_test_acc005e4[40:])
# plt.plot(np.arange(40, 50, 1), eve_test_acc005e8[40:])



plt.xlabel("Epochs")
plt.ylabel("Test accuracy")
plt.grid(ls=":")
# plt.legend(["cyclic decay", "1/t decay", "linear decay", "square root decay", "square decay","fixed step decay", "manually adjustmnet decay"])

# plt.legend(["learning rate 0.01 4epochs", "learning rate 0.01 8epochs", "learning rate 0.005 4epochs", "learning rate 0.005 8epochs"])
# plt.legend(["Lilin", "Adam", "RMSprop","Adagrad"])

# %%
# %matplotlib inline
# import matplotlib.pyplot as plt

# plt.plot(eve_test_loss)



# plt.plot(adam_test_loss)

# plt.plot(rms_test_loss)

# plt.plot(ada_test_loss)
plt.plot(eve_test_loss01e4[:50])
# plt.plot(eve_test_loss01e8)
# plt.plot(eve_test_loss005e4)
# plt.plot(eve_test_loss005e8)
plt.plot(eve_test_lossexp)

plt.plot(eve_test_losslinear)


plt.plot(eve_test_losssqrt)

plt.plot(eve_test_losssquare)

plt.plot(eve_test_lossfix)

plt.plot(eve_test_lossearly)

# plt.plot(cycle_test_loss01a4)

# plt.plot(cycle_test_loss01e4)

# plt.legend(["learning rate 0.01 4epochs", "learning rate 0.01 8epochs", "learning rate 0.005 4epochs", "learning rate 0.005 8epochs"])
# plt.legend(["exponential decay, cyclic decay", "exponential decay", "linear decay", "square root decay", "square decay","fixed step decay", "early stop decay"])




# plt.legend(["Lilin", "Adam", "RMSprop","Adagrad"])
plt.xlabel("Epochs")
plt.ylabel("Test cross-entropy loss")
plt.grid(ls=":")
# plt.legend(["Lilin with cyclic decay", "cyclic decay over Lilin"])




# plt.xlabel("Epochs")
# # plt.ylabel("Test cross-entropy loss")

# plt.ylabel("test cross-entropy loss")
# plt.yticks(np.arange(0, 2, 0.25))


# plt.grid(ls=":")
plt.legend(["cyclic decay", "1/t decay", "linear decay", "square root decay", "square decay","step decay", "step decay heuristically"])

# plt.show()


# plt.plot(loss01)
# plt.plot(tloss01)
# plt.grid(ls=":")
# plt.xlabel("Epochs")
# plt.ylabel("Cross-entropy loss")
# plt.legend(["cyclic decay"])
# plt.show()

# plt.plot(loss_linear)
# plt.plot(tloss_linear)
# plt.grid(ls=":")
# plt.xlabel("Epochs")
# plt.ylabel("Cross-entropy loss")
# plt.legend(["linear decay"])
# plt.show()

# plt.plot(loss_sqrt)
# plt.plot(tloss_sqrt)
# plt.xlabel("Epochs")
# plt.ylabel("Cross-entropy loss")
# plt.yticks(np.arange(0, 2, 0.25))
# plt.grid(ls=":")
# plt.legend(["square root decay"])
# plt.show()

# plt.plot(loss_square)
# plt.plot(tloss_square)
# plt.xlabel("Epochs")
# plt.ylabel("Cross-entropy loss")
# plt.yticks(np.arange(0, 2, 0.25))
# plt.grid(ls=":")
# plt.legend(["square decay"])
# plt.show()

# plt.plot(loss_fixed)
# plt.plot(tloss_fixed)
# plt.xlabel("Epochs")
# plt.ylabel("Cross-entropy loss")
# plt.yticks(np.arange(0, 2, 0.25))
# plt.grid(ls=":")
# plt.legend(["fixed step decay"])
# plt.show()

# plt.plot(loss_early)
# plt.plot(tloss_early)
# plt.xlabel("Epochs")
# plt.ylabel("Cross-entropy loss")
# plt.yticks(np.arange(0, 2, 0.25))
# plt.grid(ls=":")
# plt.legend(["early stop decay"])
# plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.font_manager import FontProperties
xx = [41, 45, 49]
yy = [eve_test_loss01e4[41], eve_test_loss01e4[45], eve_test_loss01e4[49]]
plt.scatter(xx,yy,s=20, c='r')


x =np.arange(40, 50, 1)
# plt.plot(x, eve_test_loss[40:51])
# plt.plot(x, adam_test_loss[40:51])

# plt.plot(x, rms_test_loss[40:51])
# plt.plot(x, ada_test_loss[40:51])

# plt.plot(x, tloss01[40:51])



plt.plot(x, eve_test_loss01e4[40:50])

# plt.plot(np.arange(40, 50, 1), eve_test_loss01e8[40:])
# plt.plot(np.arange(40, 54, 1), eve_test_loss005e4[40:])
# plt.plot(np.arange(40, 50, 1), eve_test_loss005e8[40:])

plt.plot(x, eve_test_lossexp[40:50])

plt.plot(x, eve_test_losslinear[40:50])


plt.plot(x, eve_test_losssqrt[40:50])

plt.plot(x, eve_test_losssquare[40:50])

plt.plot(x, eve_test_lossfix[40:50])

plt.plot(x, eve_test_lossearly[40:50])

# plt.legend(["learning rate 0.01 4epochs", "learning rate 0.01 8epochs", "learning rate 0.005 4epochs", "learning rate 0.005 8epochs"])

plt.xlabel("Epochs")
plt.ylabel("Test cross-entropy loss")
plt.grid(ls=":")
# plt.legend(["cyclic decay", "1/t decay", "linear decay", "square root decay", "square decay","fixed step decay", "fixed step decay manually"])
# fontP = FontProperties()
# fontP.set_size('small')
# plt.legend([plot1], "title", prop = fontP)

# plt.legend(["Lilin", "Adam", "RMSprop","Adagrad"])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt


plt.plot(eve_dtf)


plt.xlabel("Iterations")
plt.ylabel("d")
plt.grid(ls=":")

# %%
## decay zoo

# %%
# %matplotlib inline
import matplotlib.pyplot as plt


plt.plot(lr_exp)

plt.plot(lr_linear)
plt.plot(lr_sqrt)
plt.plot(lr_square)
plt.plot(lr_fix)









plt.xlabel("Iterations")
plt.ylabel("Training learning rate")
plt.grid(ls=":")
plt.legend(["1/t decay", "linear decay", "square root decay", "square decay","step decay"])
